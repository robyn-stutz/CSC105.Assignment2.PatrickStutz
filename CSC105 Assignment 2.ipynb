# %%
import pandas as pd

# %%
df = pd.read_csv("data/car_crashes.csv")

df.head()
# Out:
# C:\Users\robyn\AppData\Local\Temp\ipykernel_22160\3383996166.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/car_crashes.csv")
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516231 entries, 0 to 1516230
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   CRASH DATE                     1516231 non-null  object
#  1   CRASH TIME                     1516231 non-null  object
#  2   BOROUGH                        1014712 non-null  object
#  3   ZIP CODE                       1014479 non-null  object
#  4   LATITUDE                       1357255 non-null  float64
#  5   LONGITUDE                      1357255 non-null  float64
#  6   LOCATION                       1357255 non-null  object
#  7   ON STREET NAME                 1175335 non-null  object
#  8   CROSS STREET NAME              867895 non-null   object
#  9   OFF STREET NAME                295500 non-null   object
#  10  NUMBER OF PERSONS INJURED      1516213 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.357255e+06  1.357255e+06               1.516213e+06
# mean   4.061743e+01 -7.373321e+01               2.982905e-01
# std    2.089743e+00  3.957901e+00               6.869925e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066814e+01 -7.397324e+01               0.000000e+00
# 50%    4.072078e+01 -7.392526e+01               0.000000e+00
# 75%    4.077077e+01 -7.386504e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.000000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.516200e+06                   1.516231e+06
# mean               1.374489e-03                   5.214905e-02
# std                3.910974e-02                   2.343997e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# ...

# %%
df['NUMBER OF PEDESTRIANS INJURED'].describe()
# Out:
# count    1.516231e+06
# mean     5.214905e-02
# std      2.343997e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.700000e+01
# Name: NUMBER OF PEDESTRIANS INJURED, dtype: float64

# %%
df[["NUMBER OF MOTORIST INJURED"]].describe()
# Out:
#        NUMBER OF MOTORIST INJURED
# count                1.516231e+06
# mean                 2.170362e-01
# std                  6.492336e-01
# min                  0.000000e+00
# 25%                  0.000000e+00
# 50%                  0.000000e+00
# 75%                  0.000000e+00
# max                  4.000000e+01

# %%
df[["VEHICLE TYPE CODE 4"]].describe()
# Out:
#        VEHICLE TYPE CODE 4
# count                23314
# unique                  88
# top                  Sedan
# freq                  9108
